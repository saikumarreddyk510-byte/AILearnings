# %% [markdown]
# # Exploratory Data Analysis & Feature Engineering
#
# ## Architecture Diagram
#
# Input Datasets (Wine Quality, Flight Price, Google Play Store)
# -> Pandas DataFrames
# -> EDA Checks (shape, info, missing values, distributions)
# -> Cleaning (types, nulls, duplicates, strings)
# -> Feature Engineering (date/time extraction, encoding, numeric conversion)
# -> Visual Insights and ML-ready Data
#
# ## Deep Architecture Notes
#
# Step 1: Data load chestam - raw CSV/Excel data pandas DataFrame ga convert avutundi.
# Step 2: Data inspect chestam - rows, columns, types, missing values, duplicates check chestam.
# Step 3: Cleaning chestam - wrong types, messy strings, null values fix chestam.
# Step 4: Feature engineering chestam - raw columns nundi useful model features create chestam.
# Step 5: Visualization chestam - patterns, outliers, relationships easy ga understand chestam.
#
# > Note: Code cells original source notebooks order lo preserve chesam. Outputs clear chesam so notebook clean ga untundi. Prati code cell mundu "What/Why" explanation add chesam.

# %% [markdown]
# ## 1. Wine Quality EDA
#
# **Simple Telugu-English idea:** Wine quality dataset lo chemical columns quality score ni ela affect chestayo EDA tho chustam.
#
# **Architecture Flow:**
# Raw dataset -> Basic inspection -> Cleaning -> Feature extraction/encoding -> Visual analysis -> ML-ready understanding
#
# **Why this section important?** EDA lo first data ni observe chestam, taruvata feature engineering lo messy/raw columns ni useful ML features ga convert chestam. Ila chesthe model ki signal clear ga dorukutundi.

# %% [markdown]
# ## EDA With Red Wine Data
#
# Data Set Information:
#
# The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine.  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# These datasets can be viewed as classification or regression tasks. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
#
#
# Attribute Information:
#
# Input variables (based on physicochemical tests):
# - 1 - fixed acidity
# - 2 - volatile acidity
# - 3 - citric acid
# - 4 - residual sugar
# - 5 - chlorides
# - 6 - free sulfur dioxide
# - 7 - total sulfur dioxide
# - 8 - density
# - 9 - pH
# - 10 - sulphates
# - 11 - alcohol
#
# Output variable (based on sensory data):
# - 12 - quality (score between 0 and 10)
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 2
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `import pandas as pd` - Pandas import chestunnam; table/dataframe data ni load, clean, analyze cheyyadaniki.
# - Line 2: `from pathlib import Path` - Path import chestunnam; file paths OS-safe ga handle cheyyadaniki.
# - Line 3: `wine_dataset_path = Path('winequality-red.csv')` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 4: `wine_dataset_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv...` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 5: `if wine_dataset_path.exists():` - Condition check chestundi; data availability/value basis meeda correct branch execute cheyyadaniki.
# - Line 6: `df = pd.read_csv(wine_dataset_path, sep=';')` - CSV dataset ni DataFrame lo load chestunnam; analysis start avvadani ki data kavali.
# - Line 7: `else:` - Condition check chestundi; data availability/value basis meeda correct branch execute cheyyadaniki.
# - Line 8: `df = pd.read_csv(wine_dataset_url, sep=';')` - CSV dataset ni DataFrame lo load chestunnam; analysis start avvadani ki data kavali.
# - Line 9: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
import pandas as pd
from pathlib import Path

wine_dataset_path = Path('winequality-red.csv')
wine_dataset_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

if wine_dataset_path.exists():
    df = pd.read_csv(wine_dataset_path, sep=';')
else:
    df = pd.read_csv(wine_dataset_url, sep=';')

df.head()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 3
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Summary of the dataset` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
## Summary of the dataset
df.info()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 4
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## descriptive summary of the dataset` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.describe()` - Numerical summary stats chupistundi; mean, std, min, max laanti spread ardham avvadani ki.

# %%
## descriptive summary of the dataset
df.describe()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 5
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.shape` - Rows and columns count chupistundi; dataset size estimate cheyyadaniki.

# %%
df.shape

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 6
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## List down all the columns names` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.columns` - Column names list chestundi; available features enti ani choodadaniki.

# %%
## List down all the columns names
df.columns

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 7
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['quality'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['quality'].unique()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 8
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Missing values in the dataset` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.isnull().sum()` - Missing values check chestundi; cleaning required columns identify cheyyadaniki.

# %%
## Missing values in the dataset

df.isnull().sum()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 9
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Duplicate records` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df[df.duplicated()]` - Duplicate rows check chestundi; repeated data model/analysis ni bias cheyyakunda.

# %%
## Duplicate records
df[df.duplicated()]

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 10
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Remove the duplicates` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.drop_duplicates(inplace=True)` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
## Remove the duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 11
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.shape` - Rows and columns count chupistundi; dataset size estimate cheyyadaniki.

# %%
df.shape

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 12
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Correlation` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.corr()` - Correlation calculate chestundi; features madhya relationship strength ardham avvadani ki.

# %%
## Correlation
df.corr()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 13
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `import matplotlib.pyplot as plt` - Matplotlib plotting kosam import chestunnam; graphs create cheyyadaniki.
# - Line 2: `import seaborn as sns` - Seaborn import chestunnam; statistical visualizations neat ga draw cheyyadaniki.
# - Line 3: `plt.figure(figsize=(10,6))` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 4: `sns.heatmap(df.corr(),annot=True)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 14
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Visualization` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `#conclusion- It is an imbalanced dataset` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 3: `df.quality.value_counts().plot(kind='bar')` - Each category count chestundi; distribution and imbalance choodadaniki.
# - Line 4: `plt.xlabel("Wine Quality")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 5: `plt.ylabel("Count")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 6: `plt.show()` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
## Visualization
#conclusion- It is an imbalanced dataset
df.quality.value_counts().plot(kind='bar')
plt.xlabel("Wine Quality")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 15
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 16
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `for column in df.columns:` - Column names list chestundi; available features enti ani choodadaniki.
# - Line 2: `sns.histplot(df[column],kde=True)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
for column in df.columns:
    sns.histplot(df[column],kde=True)

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 17
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `sns.histplot(df['alcohol'])` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
sns.histplot(df['alcohol'])

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 18
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `#univariate,bivariate,multivariate analysis` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `sns.pairplot(df)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
#univariate,bivariate,multivariate analysis
sns.pairplot(df)

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 19
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `##categorical Plot` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `sns.catplot(x='quality', y='alcohol', data=df, kind="box")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
##categorical Plot
sns.catplot(x='quality', y='alcohol', data=df, kind="box")

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 20
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head()

# %% [markdown]
# ### Code Cell Explanation - 1. Wine Quality EDA / Source Cell 21
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `sns.scatterplot(x='alcohol',y='pH',hue='quality',data=df)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
sns.scatterplot(x='alcohol',y='pH',hue='quality',data=df)

# %% [markdown]
# ## 2. Flight Price EDA and Feature Engineering
#
# **Simple Telugu-English idea:** Flight ticket price prediction kosam date/time, stops, route laanti raw columns ni model-friendly features ga convert chestam.
#
# **Architecture Flow:**
# Raw dataset -> Basic inspection -> Cleaning -> Feature extraction/encoding -> Visual analysis -> ML-ready understanding
#
# **Why this section important?** EDA lo first data ni observe chestam, taruvata feature engineering lo messy/raw columns ni useful ML features ga convert chestam. Ila chesthe model ki signal clear ga dorukutundi.

# %% [markdown]
# ## EDA And Feature Engineering Flight Price Prediction
# check the dataset info below
# https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### FEATURES
# The various features of the cleaned dataset are explained below:
# 1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
# 2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
# 3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
# 4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure time and have 6 unique time labels.
# 5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
# 6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps information about the arrival time.
# 7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
# 8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
# 9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.
# 10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
# 11) Price: Target variable stores information of the ticket price.
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 3
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `# importing basics libraries` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `import pandas as pd` - Pandas import chestunnam; table/dataframe data ni load, clean, analyze cheyyadaniki.
# - Line 3: `import numpy as np` - NumPy import chestunnam; numerical calculations and NaN handling easy ga cheyyadaniki.
# - Line 4: `import matplotlib.pyplot as plt` - Matplotlib plotting kosam import chestunnam; graphs create cheyyadaniki.
# - Line 5: `import seaborn as sns` - Seaborn import chestunnam; statistical visualizations neat ga draw cheyyadaniki.
# - Line 6: `from pathlib import Path` - Path import chestunnam; file paths OS-safe ga handle cheyyadaniki.
# - Line 7: `# %matplotlib inline # Jupyter magic: plots notebook lopala display avvadani ki; normal Python syntax kosam co...` - Idi note/comment; next code step purpose ni human ki chepthundi.

# %%
# importing basics libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %matplotlib inline  # Jupyter magic: plots notebook lopala display avvadani ki; normal Python syntax kosam comment chesam.

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 4
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `flight_dataset_path = Path('assets') / 'flight_price.xlsx'` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 2: `df = pd.read_excel(flight_dataset_path)` - Excel dataset ni DataFrame lo load chestunnam; flight raw data ni pandas table ga use chestam.
# - Line 3: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
flight_dataset_path = Path('assets') / 'flight_price.xlsx'
df = pd.read_excel(flight_dataset_path)
df.head()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 5
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.tail()` - Last rows chupistundi; dataset end lo data format consistent ga unda ani check cheyyadaniki.

# %%
df.tail()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 6
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## get the basics info about data` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
## get the basics info about data
df.info()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 7
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.describe()` - Numerical summary stats chupistundi; mean, std, min, max laanti spread ardham avvadani ki.

# %%
df.describe()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 8
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 9
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Feature Engineering` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df['Date']=df['Date_of_Journey'].str.split('/').str[0]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.
# - Line 3: `df['Month']=df['Date_of_Journey'].str.split('/').str[1]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.
# - Line 4: `df['Year']=df['Date_of_Journey'].str.split('/').str[2]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.

# %%
## Feature Engineering
df['Date']=df['Date_of_Journey'].str.split('/').str[0]
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Year']=df['Date_of_Journey'].str.split('/').str[2]

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 10
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df.info()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 11
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Date']=df['Date'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.
# - Line 2: `df['Month']=df['Month'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.
# - Line 3: `df['Year']=df['Year'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
df['Date']=df['Date'].astype(int)
df['Month']=df['Month'].astype(int)
df['Year']=df['Year'].astype(int)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 12
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df.info()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 13
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Drop Date Of Journey` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.drop('Date_of_Journey',axis=1,inplace=True)` - Unwanted row/column remove chestundi; useful features matrame keep cheyyadaniki.

# %%
## Drop Date Of Journey

df.drop('Date_of_Journey',axis=1,inplace=True)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 14
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 15
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Arrival_Time']=df['Arrival_Time'].apply(lambda x:x.split(' ')[0])` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.

# %%
df['Arrival_Time']=df['Arrival_Time'].apply(lambda x:x.split(' ')[0])

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 16
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Arrival_hour']=df['Arrival_Time'].str.split(':').str[0]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.
# - Line 2: `df['Arrival_min']=df['Arrival_Time'].str.split(':').str[1]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.

# %%
df['Arrival_hour']=df['Arrival_Time'].str.split(':').str[0]
df['Arrival_min']=df['Arrival_Time'].str.split(':').str[1]

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 17
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head(2)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 18
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Arrival_hour']=df['Arrival_hour'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.
# - Line 2: `df['Arrival_min']=df['Arrival_min'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
df['Arrival_hour']=df['Arrival_hour'].astype(int)
df['Arrival_min']=df['Arrival_min'].astype(int)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 19
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.drop('Arrival_Time',axis=1,inplace=True)` - Unwanted row/column remove chestundi; useful features matrame keep cheyyadaniki.

# %%
df.drop('Arrival_Time',axis=1,inplace=True)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 20
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head(2)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 21
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Departure_hour']=df['Dep_Time'].str.split(':').str[0]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.
# - Line 2: `df['Departure_min']=df['Dep_Time'].str.split(':').str[1]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.

# %%
df['Departure_hour']=df['Dep_Time'].str.split(':').str[0]
df['Departure_min']=df['Dep_Time'].str.split(':').str[1]

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 22
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Departure_hour']=df['Departure_hour'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.
# - Line 2: `df['Departure_min']=df['Departure_min'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
df['Departure_hour']=df['Departure_hour'].astype(int)
df['Departure_min']=df['Departure_min'].astype(int)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 23
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df.info()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 24
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.drop('Dep_Time',axis=1,inplace=True)` - Unwanted row/column remove chestundi; useful features matrame keep cheyyadaniki.

# %%
df.drop('Dep_Time',axis=1,inplace=True)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 25
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head(2)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 26
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Total_Stops'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['Total_Stops'].unique()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 27
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df[df['Total_Stops'].isnull()]` - Missing values check chestundi; cleaning required columns identify cheyyadaniki.

# %%
df[df['Total_Stops'].isnull()]

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 28
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Total_Stops'].mode()` - Most frequent value find chestundi; categorical missing values fill cheyyadaniki useful.

# %%
df['Total_Stops'].mode()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 29
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Total_Stops'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['Total_Stops'].unique()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 30
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Total_Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,np.nan:1}...` - Mapping apply chestundi; text categories ni numeric/order values ga convert cheyyadaniki.

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,np.nan:1})

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 31
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df[df['Total_Stops'].isnull()]` - Missing values check chestundi; cleaning required columns identify cheyyadaniki.

# %%
df[df['Total_Stops'].isnull()]

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 32
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head(2)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 33
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.drop('Route',axis=1,inplace=True)` - Unwanted row/column remove chestundi; useful features matrame keep cheyyadaniki.

# %%
df.drop('Route',axis=1,inplace=True)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 34
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head(2)

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 35
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Duration'].str.split(' ').str[0].str.split('h').str[0]` - Text ni parts ga split chestundi; date/time/duration nundi separate features extract cheyyadaniki.

# %%
df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 36
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Airline'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['Airline'].unique()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 37
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Source'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['Source'].unique()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 38
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Additional_Info'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['Additional_Info'].unique()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 39
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `from sklearn.preprocessing import OneHotEncoder` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 40
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `encoder=OneHotEncoder()` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
encoder=OneHotEncoder()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 41
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `encoder.fit_transform(df[['Airline','Source','Destination']]).toarray()` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
encoder.fit_transform(df[['Airline','Source','Destination']]).toarray()

# %% [markdown]
# ### Code Cell Explanation - 2. Flight Price EDA and Feature Engineering / Source Cell 42
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `pd.DataFrame(encoder.fit_transform(df[['Airline','Source','Destination']]).toarray(),columns=encoder.get_featu...` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
pd.DataFrame(encoder.fit_transform(df[['Airline','Source','Destination']]).toarray(),columns=encoder.get_feature_names_out())

# %% [markdown]
# ## 3. Google Play Store EDA and Feature Engineering
#
# **Simple Telugu-English idea:** Google Play Store apps data lo installs, size, price, reviews laanti messy columns clean chesi analysis-ready format lo ki teesukostam.
#
# **Architecture Flow:**
# Raw dataset -> Basic inspection -> Cleaning -> Feature extraction/encoding -> Visual analysis -> ML-ready understanding
#
# **Why this section important?** EDA lo first data ni observe chestam, taruvata feature engineering lo messy/raw columns ni useful ML features ga convert chestam. Ila chesthe model ki signal clear ga dorukutundi.

# %% [markdown]
# ## EDA And Feature Engineering Of Google Play Store Dataset
#
# 1) Problem statement.
# Today, 1.85 million different apps are available for users to download. Android users have even more from which to choose, with 2.56 million available through the Google Play Store. These apps have come to play a huge role in the way we live our lives today. Our Objective is to find the Most Popular Category, find the App with largest number of installs , the App with largest size etc.
# 2) Data Collection.
#
# The data consists of 20 column and 10841 rows.
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Steps We Are Going to Follow
# 1. Data Clearning
# 2. Exploratory Data Analysis
# 3. Featur eEngineering
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 3
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `import pandas as pd` - Pandas import chestunnam; table/dataframe data ni load, clean, analyze cheyyadaniki.
# - Line 2: `import numpy as np` - NumPy import chestunnam; numerical calculations and NaN handling easy ga cheyyadaniki.
# - Line 3: `import matplotlib.pyplot as plt` - Matplotlib plotting kosam import chestunnam; graphs create cheyyadaniki.
# - Line 4: `import seaborn as sns` - Seaborn import chestunnam; statistical visualizations neat ga draw cheyyadaniki.
# - Line 5: `import warnings` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 6: `warnings.filterwarnings("ignore")` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 7: `# %matplotlib inline # Jupyter magic: plots notebook lopala display avvadani ki; normal Python syntax kosam co...` - Idi note/comment; next code step purpose ni human ki chepthundi.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline  # Jupyter magic: plots notebook lopala display avvadani ki; normal Python syntax kosam comment chesam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 4
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')` - CSV dataset ni DataFrame lo load chestunnam; analysis start avvadani ki data kavali.
# - Line 2: `df.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.head()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 5
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.shape` - Rows and columns count chupistundi; dataset size estimate cheyyadaniki.

# %%
df.shape

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 6
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df.info()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 7
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `##summary of the dataset` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.describe()` - Numerical summary stats chupistundi; mean, std, min, max laanti spread ardham avvadani ki.

# %%
##summary of the dataset
df.describe()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 8
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `##Missing Values` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df.isnull().sum()` - Missing values check chestundi; cleaning required columns identify cheyyadaniki.

# %%
##Missing Values
df.isnull().sum()

# %% [markdown]
# ## Insights and observation
# The dataset has msising values
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 10
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df.head(2)

# %% [markdown]
# ## Data Cleaning
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 12
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Reviews'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df['Reviews'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 13
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Reviews'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
df['Reviews'].astype(int)

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 14
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df['Reviews'].str.isnumeric().sum()` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
df['Reviews'].str.isnumeric().sum()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 15
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df[~df['Reviews'].str.isnumeric()]` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
df[~df['Reviews'].str.isnumeric()]

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 16
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy=df.copy()` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
df_copy=df.copy()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 17
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy=df_copy.drop(df_copy.index[10472])` - Unwanted row/column remove chestundi; useful features matrame keep cheyyadaniki.

# %%
df_copy=df_copy.drop(df_copy.index[10472])

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 18
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy[~df_copy['Reviews'].str.isnumeric()]` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
df_copy[~df_copy['Reviews'].str.isnumeric()]

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 19
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Convert Review Datatype to int` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df_copy['Reviews']=df_copy['Reviews'].astype(int)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
## Convert Review Datatype to int
df_copy['Reviews']=df_copy['Reviews'].astype(int)

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 20
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df_copy.info()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 21
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Size'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df_copy['Size'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 22
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `# 19000K == 19M # K ante thousand, M ante million ani size cleaning logic ardham kosam note.` - Idi note/comment; next code step purpose ni human ki chepthundi.

# %%
# 19000K == 19M  # K ante thousand, M ante million ani size cleaning logic ardham kosam note.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 23
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Size'].isnull().sum()` - Missing values check chestundi; cleaning required columns identify cheyyadaniki.

# %%
df_copy['Size'].isnull().sum()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 24
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Size']=df_copy['Size'].str.replace('M','000')` - String/value replace chestundi; messy symbols or labels clean cheyyadaniki.
# - Line 2: `df_copy['Size']=df_copy['Size'].str.replace('k','')` - String/value replace chestundi; messy symbols or labels clean cheyyadaniki.
# - Line 3: `df_copy['Size']=df_copy['Size'].replace('Varies with device',np.nan)` - String/value replace chestundi; messy symbols or labels clean cheyyadaniki.
# - Line 4: `df_copy['Size']=df_copy['Size'].astype(float)` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
df_copy['Size']=df_copy['Size'].str.replace('M','000')
df_copy['Size']=df_copy['Size'].str.replace('k','')
df_copy['Size']=df_copy['Size'].replace('Varies with device',np.nan)
df_copy['Size']=df_copy['Size'].astype(float)

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 25
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Size']` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
df_copy['Size']

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 26
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Installs'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df_copy['Installs'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 27
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Price'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df_copy['Price'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 28
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `chars_to_remove=['+',',','$']` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 2: `cols_to_clean=['Installs','Price']` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 3: `for item in chars_to_remove:` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 4: `for cols in cols_to_clean:` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 5: `df_copy[cols]=df_copy[cols].str.replace(item,'')` - String/value replace chestundi; messy symbols or labels clean cheyyadaniki.

# %%
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df_copy[cols]=df_copy[cols].str.replace(item,'')

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 29
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Price'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df_copy['Price'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 30
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Installs'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
df_copy['Installs'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 31
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Installs']=df_copy['Installs'].astype('int')` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.
# - Line 2: `df_copy['Price']=df_copy['Price'].astype('float')` - Column data type convert chestundi; numeric operations/model input correct ga undadaniki.

# %%
df_copy['Installs']=df_copy['Installs'].astype('int')
df_copy['Price']=df_copy['Price'].astype('float')

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 32
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df_copy.info()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 33
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Handlling Last update feature` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `df_copy['Last Updated'].unique()` - Unique values chupistundi; categorical values/ranges ardham avvadani ki.

# %%
## Handlling Last update feature
df_copy['Last Updated'].unique()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 34
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])` - Text date ni datetime type ga convert chestundi; day/month/year extract cheyyadaniki.
# - Line 2: `df_copy['Day']=df_copy['Last Updated'].dt.day` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 3: `df_copy['Month']=df_copy['Last Updated'].dt.month` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 4: `df_copy['Year']=df_copy['Last Updated'].dt.year` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])
df_copy['Day']=df_copy['Last Updated'].dt.day
df_copy['Month']=df_copy['Last Updated'].dt.month
df_copy['Year']=df_copy['Last Updated'].dt.year

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 35
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.info()` - Data types and non-null counts chupistundi; missing values and column types identify cheyyadaniki.

# %%
df_copy.info()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 36
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df_copy.head()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 37
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.to_csv('data/google_cleaned.csv')` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
df_copy.to_csv('data/google_cleaned.csv')

# %% [markdown]
# ## EDA
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 39
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df_copy.head()

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 40
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy[df_copy.duplicated('App')].shape` - Rows and columns count chupistundi; dataset size estimate cheyyadaniki.

# %%
df_copy[df_copy.duplicated('App')].shape

# %% [markdown]
# ## Observation
# The dataset has duplicate records
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 42
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy=df_copy.drop_duplicates(subset=['App'],keep='first')` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
df_copy=df_copy.drop_duplicates(subset=['App'],keep='first')

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 43
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.shape` - Rows and columns count chupistundi; dataset size estimate cheyyadaniki.

# %%
df_copy.shape

# %% [markdown]
# ## Explore Data
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 45
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `numeric_features = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O']` - Column names list chestundi; available features enti ani choodadaniki.
# - Line 2: `categorical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']` - Column names list chestundi; available features enti ani choodadaniki.
# - Line 3: `# print columns` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 4: `print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 5: `print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
numeric_features = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O']
categorical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))

# %% [markdown]
# ## 3.2 Feature Information
# 1. App :- Name of the App
# 2. Category :- Category under which the App falls.
# 3. Rating :- Application's rating on playstore
# 4. Reviews :- Number of reviews of the App.
# 5. Size :- Size of the App.
# 6. Install :- Number of Installs of the App
# 7. Type :- If the App is free/paid
# 8. Price :- Price of the app (0 if it is Free)
# 9. Content Rating :- Appropiate Target Audience of the App.
# 10. Genres:- Genre under which the App falls.
# 11. Last Updated :- Date when the App was last updated
# 12. Current Ver :- Current Version of the Application
# 13. Android Ver :- Minimum Android Version required to run the App
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 47
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Proportion of count data on categorical columns` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `for col in categorical_features:` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 3: `print(df[col].value_counts(normalize=True)*100)` - Each category count chestundi; distribution and imbalance choodadaniki.
# - Line 4: `print('---------------------------')` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
## Proportion of count data on categorical columns
for col in categorical_features:
    print(df[col].value_counts(normalize=True)*100)
    print('---------------------------')

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 48
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Proportion of count data on numerical columns` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `plt.figure(figsize=(15, 15))` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 3: `plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 4: `for i in range(0, len(numeric_features)):` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 5: `plt.subplot(5, 3, i+1)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 6: `sns.kdeplot(x=df_copy[numeric_features[i]],shade=True, color='r')` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 7: `plt.xlabel(numeric_features[i])` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 8: `plt.tight_layout()` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
## Proportion of count data on numerical columns
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df_copy[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# ## Observations
# - Rating and Year is left skewed while Reviews,Size,Installs and Price are right skewed
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 50
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `# categorical columns` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `plt.figure(figsize=(20, 15))` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 3: `plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 4: `category = [ 'Type', 'Content Rating']` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 5: `for i in range(0, len(category)):` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 6: `plt.subplot(2, 2, i+1)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 7: `sns.countplot(x=df[category[i]],palette="Set2")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 8: `plt.xlabel(category[i])` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 9: `plt.xticks(rotation=45)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 10: `plt.tight_layout()` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# ## Which is the most popular app category?
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 52
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.head(2)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df_copy.head(2)

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 53
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],figsize=(15,16),autopct='%1.1f')` - Each category count chestundi; distribution and imbalance choodadaniki.

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],figsize=(15,16),autopct='%1.1f')

# %% [markdown]
# ## Observations
#
# 1. There are more kinds of apps in playstore which are under category of family, games & tools
# 2. Beatuty,comics,arts and weather kinds of apps are very less in playstore
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 55
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## Top 10 App Categories` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `category = pd.DataFrame(df_copy['Category'].value_counts()) #Dataframe of apps on the basis of category` - Each category count chestundi; distribution and imbalance choodadaniki.
# - Line 3: `category.rename(columns = {'Category':'Count'},inplace=True)` - Column labels rename chestundi; names clean and understandable ga undadaniki.

# %%
## Top 10 App Categories
category = pd.DataFrame(df_copy['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 56
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `category` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.

# %%
category

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 57
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `## top 10 app` - Idi note/comment; next code step purpose ni human ki chepthundi.
# - Line 2: `plt.figure(figsize=(15,6))` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 3: `sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 4: `plt.title('Top 10 App categories')` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 5: `plt.xticks(rotation=90)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 6: `plt.show()` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
## top 10 app
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Insights
# 1. Family category has the most number of apps with 18% of apps belonging to it, followed by Games category which has 11% of the apps.
# 2. Least number of apps belong to the Beauty category with less than 1% of the total apps belonging to it.
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ## Internal Assignments
# 1. Which Category has largest number of installations??
# 2. What are the Top 5 most installed Apps in Each popular Categories ??
# 3. How many apps are there on Google Play Store which get 5 ratings??
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ## Which Category has largest number of installations??
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 61
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_cat_installs = df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()` - Group-wise aggregation chestundi; category wise behavior compare cheyyadaniki.
# - Line 2: `df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 3: `df2 = df_cat_installs.head(10)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.
# - Line 4: `plt.figure(figsize = (14,10))` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 5: `sns.set_context("talk")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 6: `sns.set_style("darkgrid")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 7: `ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 8: `ax.set_xlabel('No. of Installations in Billions')` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 9: `ax.set_ylabel('')` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 10: `ax.set_title("Most Popular Categories in Play Store", size = 20)` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.

# %%
df_cat_installs = df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions
df2 = df_cat_installs.head(10)
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)

# %% [markdown]
# ## Insights
# 1. Out of all the categories "GAME" has the most number of Installations.
# 2. With almost 35 Billion Installations GAME is the most popular Category in Google App store
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ## What are the Top 5 most installed Apps in Each popular Categories ??
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 64
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `dfa = df_copy.groupby(['Category' ,'App'])['Installs'].sum().reset_index()` - Group-wise aggregation chestundi; category wise behavior compare cheyyadaniki.
# - Line 2: `dfa = dfa.sort_values('Installs', ascending = False)` - Values sort chestundi; top/bottom patterns easy ga inspect cheyyadaniki.
# - Line 3: `apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 4: `sns.set_context("poster")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 5: `sns.set_style("darkgrid")` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 6: `plt.figure(figsize=(40,30))` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 7: `for i,app in enumerate(apps):` - Ee Python statement EDA/feature engineering step ni run chestundi; output next decision ki help chestundi.
# - Line 8: `df2 = dfa[dfa.Category == app]` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 9: `df3 = df2.head(5)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.
# - Line 10: `plt.subplot(4,2,i+1)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 11: `sns.barplot(data= df3,x= 'Installs' ,y='App' )` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 12: `plt.xlabel('Installation in Millions')` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 13: `plt.ylabel('')` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 14: `plt.title(app,size = 20)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 15: `plt.tight_layout()` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 16: `plt.subplots_adjust(hspace= .3)` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.
# - Line 17: `plt.show()` - Visualization create chestundi; patterns/outliers/relationships visually choodadaniki.

# %%
dfa = df_copy.groupby(['Category' ,'App'])['Installs'].sum().reset_index()
dfa = dfa.sort_values('Installs', ascending = False)
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %% [markdown]
# ## Insights
# - Most popular game is Subway Surfers.
# - Most popular communication app is Hangouts.
# - Most popular productivity app is Google Drive.
# - Most popular social app is Instagram.
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ## How many apps are there on Google Play Store which get 5 ratings??
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 67
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `rating = df_copy.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_...` - Group-wise aggregation chestundi; category wise behavior compare cheyyadaniki.
# - Line 2: `toprating_apps = rating[rating.Rating == 5.0]` - Result ni variable/column lo store chestundi; next analysis step lo reuse cheyyadaniki.
# - Line 3: `print("Number of 5 rated apps",toprating_apps.shape[0])` - Rows and columns count chupistundi; dataset size estimate cheyyadaniki.
# - Line 4: `toprating_apps.head(1)` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
rating = df_copy.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

toprating_apps = rating[rating.Rating == 5.0]
print("Number of 5 rated apps",toprating_apps.shape[0])
toprating_apps.head(1)

# %% [markdown]
# ## Result
# - There are 271 five rated apps on Google Play store
# - Top most is 'CT Brain Interpretation' from 'Family' Category
#
# **Telugu-English explanation:** Ee markdown section lo concept/background explain chestundi. Mundu concept ardham chesukoni, next code cell lo practical ga data meeda apply chestam.

# %% [markdown]
# ### Code Cell Explanation - 3. Google Play Store EDA and Feature Engineering / Source Cell 69
#
# **What are we doing?** Ee cell lo dataset inspect/clean/transform/visualize cheyyadaniki oka practical step run chestunnam.
#
# **Why are we doing?** EDA and Feature Engineering lo every small step data quality or model-ready features improve cheyyadaniki help chestundi.
#
# **Line-by-line simple explanation:**
# - Line 1: `df_copy.head()` - First few rows chupistundi; columns and sample values quick ga ardham avvadani ki.

# %%
df_copy.head()
